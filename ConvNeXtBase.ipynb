# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install timm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting timm
#   Downloading timm-0.9.2-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 83.5 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.10/dist-packages (from timm) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm) (0.15.2+cu118)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm) (6.0)
# Collecting huggingface-hub (from timm)
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 29.8 MB/s eta 0:00:00
# Collecting safetensors (from timm)
#   Downloading safetensors-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 82.3 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.7->timm) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.7->timm) (16.0.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (2023.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (2.27.1)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (4.65.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (23.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision->timm) (1.22.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->timm) (8.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.7->timm) (2.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.7->timm) (1.3.0)
# Installing collected packages: safetensors, huggingface-hub, timm
# Successfully installed huggingface-hub-0.14.1 safetensors-0.3.1 timm-0.9.2

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

import random
import pandas as pd
import numpy as np
import os
import re
import glob
import cv2
import timm

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler
from PIL import Image

import albumentations as A
from albumentations.pytorch.transforms import ToTensorV2
import torchvision.models as models

from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report
from tqdm.auto import tqdm

import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ## **setting**

# %%
# %cd /content/drive/MyDrive/data
# Out:
# /content/drive/MyDrive/data

# %%
#!unzip open.zip -d ./data
# Out:
# Archive:  open.zip
#   inflating: ./data/sample_submission.csv
#   inflating: ./data/test.csv
#    creating: ./data/test/
#   inflating: ./data/test/000.png
#   inflating: ./data/test/001.png
#   inflating: ./data/test/002.png
#   inflating: ./data/test/003.png
#   inflating: ./data/test/004.png
#   inflating: ./data/test/005.png
#   inflating: ./data/test/006.png
#   inflating: ./data/test/007.png
#   inflating: ./data/test/008.png
#   inflating: ./data/test/009.png
#   inflating: ./data/test/010.png
#   inflating: ./data/test/011.png
#   inflating: ./data/test/012.png
#   inflating: ./data/test/013.png
#   inflating: ./data/test/014.png
#   inflating: ./data/test/015.png
#   inflating: ./data/test/016.png
#   inflating: ./data/test/017.png
#   inflating: ./data/test/018.png
#   inflating: ./data/test/019.png
#   inflating: ./data/test/020.png
#   inflating: ./data/test/021.png
#   inflating: ./data/test/022.png
#   inflating: ./data/test/023.png
#   inflating: ./data/test/024.png
#   inflating: ./data/test/025.png
#   inflating: ./data/test/026.png
#   inflating: ./data/test/027.png
#   inflating: ./data/test/028.png
#   inflating: ./data/test/029.png
#   inflating: ./data/test/030.png
#   inflating: ./data/test/031.png
#   inflating: ./data/test/032.png
#   inflating: ./data/test/033.png
#   inflating: ./data/test/034.png
#   inflating: ./data/test/035.png
#   inflating: ./data/test/036.png
#   inflating: ./data/test/037.png
#   inflating: ./data/test/038.png
#   inflating: ./data/test/039.png
#   inflating: ./data/test/040.png
#   inflating: ./data/test/041.png
#   inflating: ./data/test/042.png
#   inflating: ./data/test/043.png
#   inflating: ./data/test/044.png
#   inflating: ./data/test/045.png
#   inflating: ./data/test/046.png
#   inflating: ./data/test/047.png
#   inflating: ./data/test/048.png
#   inflating: ./data/test/049.png
#   inflating: ./data/test/050.png
#   inflating: ./data/test/051.png
#   inflating: ./data/test/052.png
#   inflating: ./data/test/053.png
#   inflating: ./data/test/054.png
#   inflating: ./data/test/055.png
#   inflating: ./data/test/056.png
#   inflating: ./data/test/057.png
#   inflating: ./data/test/058.png
#   inflating: ./data/test/059.png
#   inflating: ./data/test/060.png
#   inflating: ./data/test/061.png
#   inflating: ./data/test/062.png
#   inflating: ./data/test/063.png
#   inflating: ./data/test/064.png
#   inflating: ./data/test/065.png
#   inflating: ./data/test/066.png
#   inflating: ./data/test/067.png
#   inflating: ./data/test/068.png
#   inflating: ./data/test/069.png
#   inflating: ./data/test/070.png
#   inflating: ./data/test/071.png
#   inflating: ./data/test/072.png
#   inflating: ./data/test/073.png
#   inflating: ./data/test/074.png
#   inflating: ./data/test/075.png
#   inflating: ./data/test/076.png
#   inflating: ./data/test/077.png
#   inflating: ./data/test/078.png
#   inflating: ./data/test/079.png
#   inflating: ./data/test/080.png
#   inflating: ./data/test/081.png
#   inflating: ./data/test/082.png
#   inflating: ./data/test/083.png
#   inflating: ./data/test/084.png
#   inflating: ./data/test/085.png
#   inflating: ./data/test/086.png
#   inflating: ./data/test/087.png
#   inflating: ./data/test/088.png
#   inflating: ./data/test/089.png
#   inflating: ./data/test/090.png
#   inflating: ./data/test/091.png
#   inflating: ./data/test/092.png
#   inflating: ./data/test/093.png
#   inflating: ./data/test/094.png
#   inflating: ./data/test/095.png
#   inflating: ./data/test/096.png
#   inflating: ./data/test/097.png
#   inflating: ./data/test/098.png
#   inflating: ./data/test/099.png
#   inflating: ./data/test/100.png
#   inflating: ./data/test/101.png
#   inflating: ./data/test/102.png
#   inflating: ./data/test/103.png
#   inflating: ./data/test/104.png
#   inflating: ./data/test/105.png
#   inflating: ./data/test/106.png
#   inflating: ./data/test/107.png
#   inflating: ./data/test/108.png
#   inflating: ./data/test/109.png
#   inflating: ./data/test/110.png
#   inflating: ./data/test/111.png
#   inflating: ./data/test/112.png
#   inflating: ./data/test/113.png
#   inflating: ./data/test/114.png
#   inflating: ./data/test/115.png
#   inflating: ./data/test/116.png
#   inflating: ./data/test/117.png
#   inflating: ./data/test/118.png
#   inflating: ./data/test/119.png
#   inflating: ./data/test/120.png
#   inflating: ./data/test/121.png
#   inflating: ./data/test/122.png
#   inflating: ./data/test/123.png
#   inflating: ./data/test/124.png
#   inflating: ./data/test/125.png
#   inflating: ./data/test/126.png
#   inflating: ./data/test/127.png
#   inflating: ./data/test/128.png
#   inflating: ./data/test/129.png
#   inflating: ./data/test/130.png
#   inflating: ./data/test/131.png
#   inflating: ./data/test/132.png
#   inflating: ./data/test/133.png
#   inflating: ./data/test/134.png
#   inflating: ./data/test/135.png
#   inflating: ./data/test/136.png
#   inflating: ./data/test/137.png
#   inflating: ./data/test/138.png
#   inflating: ./data/test/139.png
#   inflating: ./data/test/140.png
#   inflating: ./data/test/141.png
#   inflating: ./data/test/142.png
#   inflating: ./data/test/143.png
#   inflating: ./data/test/144.png
#   inflating: ./data/test/145.png
#   inflating: ./data/test/146.png
#   inflating: ./data/test/147.png
#   inflating: ./data/test/148.png
#   inflating: ./data/test/149.png
#   inflating: ./data/test/150.png
#   inflating: ./data/test/151.png
#   inflating: ./data/test/152.png
#   inflating: ./data/test/153.png
#   inflating: ./data/test/154.png
#   inflating: ./data/test/155.png
#   inflating: ./data/test/156.png
#   inflating: ./data/test/157.png
#   inflating: ./data/test/158.png
#   inflating: ./data/test/159.png
#   inflating: ./data/test/160.png
#   inflating: ./data/test/161.png
#   inflating: ./data/test/162.png
#   inflating: ./data/test/163.png
#   inflating: ./data/test/164.png
#   inflating: ./data/test/165.png
#   inflating: ./data/test/166.png
#   inflating: ./data/test/167.png
#   inflating: ./data/test/168.png
#   inflating: ./data/test/169.png
#   inflating: ./data/test/170.png
#   inflating: ./data/test/171.png
#   inflating: ./data/test/172.png
#   inflating: ./data/test/173.png
#   inflating: ./data/test/174.png
#   inflating: ./data/test/175.png
#   inflating: ./data/test/176.png
#   inflating: ./data/test/177.png
#   inflating: ./data/test/178.png
#   inflating: ./data/test/179.png
#   inflating: ./data/test/180.png
#   inflating: ./data/test/181.png
#   inflating: ./data/test/182.png
#   inflating: ./data/test/183.png
#   inflating: ./data/test/184.png
#   inflating: ./data/test/185.png
#   inflating: ./data/test/186.png
#   inflating: ./data/test/187.png
#   inflating: ./data/test/188.png
#   inflating: ./data/test/189.png
#   inflating: ./data/test/190.png
#   inflating: ./data/test/191.png
#   inflating: ./data/test/192.png
#   inflating: ./data/test/193.png
#   inflating: ./data/test/194.png
#   inflating: ./data/test/195.png
#   inflating: ./data/test/196.png
#   inflating: ./data/test/197.png
#   inflating: ./data/test/198.png
#   inflating: ./data/test/199.png
#   inflating: ./data/test/200.png
#   inflating: ./data/test/201.png
#   inflating: ./data/test/202.png
#   inflating: ./data/test/203.png
#   inflating: ./data/test/204.png
#   inflating: ./data/test/205.png
#   inflating: ./data/test/206.png
#   inflating: ./data/test/207.png
#   inflating: ./data/test/208.png
#   inflating: ./data/test/209.png
#   inflating: ./data/test/210.png
#   inflating: ./data/test/211.png
#   inflating: ./data/test/212.png
#   inflating: ./data/test/213.png
#   inflating: ./data/test/214.png
#   inflating: ./data/test/215.png
#   inflating: ./data/test/216.png
#   inflating: ./data/test/217.png
#   inflating: ./data/test/218.png
#   inflating: ./data/test/219.png
#   inflating: ./data/test/220.png
#   inflating: ./data/test/221.png
#   inflating: ./data/test/222.png
#   inflating: ./data/test/223.png
#   inflating: ./data/test/224.png
#   inflating: ./data/test/225.png
#   inflating: ./data/test/226.png
#   inflating: ./data/test/227.png
#   inflating: ./data/test/228.png
#   inflating: ./data/test/229.png
#   inflating: ./data/test/230.png
#   inflating: ./data/test/231.png
#   inflating: ./data/test/232.png
#   inflating: ./data/test/233.png
#   inflating: ./data/test/234.png
#   inflating: ./data/test/235.png
#   inflating: ./data/test/236.png
#   inflating: ./data/test/237.png
#   inflating: ./data/test/238.png
#   inflating: ./data/test/239.png
#   inflating: ./data/test/240.png
#   inflating: ./data/test/241.png
#   inflating: ./data/test/242.png
#   inflating: ./data/test/243.png
#   inflating: ./data/test/244.png
#   inflating: ./data/test/245.png
#   inflating: ./data/test/246.png
#   inflating: ./data/test/247.png
#   inflating: ./data/test/248.png
#   inflating: ./data/test/249.png
#   inflating: ./data/test/250.png
#   inflating: ./data/test/251.png
#   inflating: ./data/test/252.png
#   inflating: ./data/test/253.png
#   inflating: ./data/test/254.png
#   inflating: ./data/test/255.png
#   inflating: ./data/test/256.png
#   inflating: ./data/test/257.png
#   inflating: ./data/test/258.png
#   inflating: ./data/test/259.png
#   inflating: ./data/test/260.png
#   inflating: ./data/test/261.png
#   inflating: ./data/test/262.png
#   inflating: ./data/test/263.png
#   inflating: ./data/test/264.png
#   inflating: ./data/test/265.png
#   inflating: ./data/test/266.png
#   inflating: ./data/test/267.png
#   inflating: ./data/test/268.png
#   inflating: ./data/test/269.png
#   inflating: ./data/test/270.png
#   inflating: ./data/test/271.png
#   inflating: ./data/test/272.png
#   inflating: ./data/test/273.png
#   inflating: ./data/test/274.png
#   inflating: ./data/test/275.png
#   inflating: ./data/test/276.png
#   inflating: ./data/test/277.png
#   inflating: ./data/test/278.png
#   inflating: ./data/test/279.png
#   inflating: ./data/test/280.png
#   inflating: ./data/test/281.png
#   inflating: ./data/test/282.png
#   inflating: ./data/test/283.png
#   inflating: ./data/test/284.png
#   inflating: ./data/test/285.png
#   inflating: ./data/test/286.png
#   inflating: ./data/test/287.png
#   inflating: ./data/test/288.png
#   inflating: ./data/test/289.png
#   inflating: ./data/test/290.png
#   inflating: ./data/test/291.png
#   inflating: ./data/test/292.png
#   inflating: ./data/test/293.png
#   inflating: ./data/test/294.png
#   inflating: ./data/test/295.png
#   inflating: ./data/test/296.png
#   inflating: ./data/test/297.png
#   inflating: ./data/test/298.png
#   inflating: ./data/test/299.png
#   inflating: ./data/test/300.png
#   inflating: ./data/test/301.png
#   inflating: ./data/test/302.png
#   inflating: ./data/test/303.png
#   inflating: ./data/test/304.png
#   inflating: ./data/test/305.png
#   inflating: ./data/test/306.png
#   inflating: ./data/test/307.png
#   inflating: ./data/test/308.png
#   inflating: ./data/test/309.png
#   inflating: ./data/test/310.png
#   inflating: ./data/test/311.png
#   inflating: ./data/test/312.png
#   inflating: ./data/test/313.png
#   inflating: ./data/test/314.png
#   inflating: ./data/test/315.png
#   inflating: ./data/test/316.png
#   inflating: ./data/test/317.png
#   inflating: ./data/test/318.png
#   inflating: ./data/test/319.png
#   inflating: ./data/test/320.png
#   inflating: ./data/test/321.png
#   inflating: ./data/test/322.png
#   inflating: ./data/test/323.png
#   inflating: ./data/test/324.png
#   inflating: ./data/test/325.png
#   inflating: ./data/test/326.png
#   inflating: ./data/test/327.png
#   inflating: ./data/test/328.png
#   inflating: ./data/test/329.png
#   inflating: ./data/test/330.png
#   inflating: ./data/test/331.png
#   inflating: ./data/test/332.png
#   inflating: ./data/test/333.png
#   inflating: ./data/test/334.png
#   inflating: ./data/test/335.png
#   inflating: ./data/test/336.png
#   inflating: ./data/test/337.png
#   inflating: ./data/test/338.png
#   inflating: ./data/test/339.png
#   inflating: ./data/test/340.png
#   inflating: ./data/test/341.png
#   inflating: ./data/test/342.png
#   inflating: ./data/test/343.png
#   inflating: ./data/test/344.png
#   inflating: ./data/test/345.png
#   inflating: ./data/test/346.png
#   inflating: ./data/test/347.png
#   inflating: ./data/test/348.png
#   inflating: ./data/test/349.png
#   inflating: ./data/test/350.png
#   inflating: ./data/test/351.png
#   inflating: ./data/test/352.png
#   inflating: ./data/test/353.png
#   inflating: ./data/test/354.png
#   inflating: ./data/test/355.png
#   inflating: ./data/test/356.png
#   inflating: ./data/test/357.png
#   inflating: ./data/test/358.png
#   inflating: ./data/test/359.png
#   inflating: ./data/test/360.png
#   inflating: ./data/test/361.png
#   inflating: ./data/test/362.png
#   inflating: ./data/test/363.png
#   inflating: ./data/test/364.png
#   inflating: ./data/test/365.png
#   inflating: ./data/test/366.png
#   inflating: ./data/test/367.png
#   inflating: ./data/test/368.png
#   inflating: ./data/test/369.png
#   inflating: ./data/test/370.png
#   inflating: ./data/test/371.png
#   inflating: ./data/test/372.png
#   inflating: ./data/test/373.png
#   inflating: ./data/test/374.png
#   inflating: ./data/test/375.png
#   inflating: ./data/test/376.png
#   inflating: ./data/test/377.png
#   inflating: ./data/test/378.png
#   inflating: ./data/test/379.png
#   inflating: ./data/test/380.png
#   inflating: ./data/test/381.png
#   inflating: ./data/test/382.png
#   inflating: ./data/test/383.png
#   inflating: ./data/test/384.png
#   inflating: ./data/test/385.png
#   inflating: ./data/test/386.png
#   inflating: ./data/test/387.png
#   inflating: ./data/test/388.png
#   inflating: ./data/test/389.png
#   inflating: ./data/test/390.png
#   inflating: ./data/test/391.png
#   inflating: ./data/test/392.png
#   inflating: ./data/test/393.png
#   inflating: ./data/test/394.png
#   inflating: ./data/test/395.png
#   inflating: ./data/test/396.png
#   inflating: ./data/test/397.png
#   inflating: ./data/test/398.png
#   inflating: ./data/test/399.png
#   inflating: ./data/test/400.png
#   inflating: ./data/test/401.png
#   inflating: ./data/test/402.png
#   inflating: ./data/test/403.png
#   inflating: ./data/test/404.png
#   inflating: ./data/test/405.png
#   inflating: ./data/test/406.png
#   inflating: ./data/test/407.png
#   inflating: ./data/test/408.png
#   inflating: ./data/test/409.png
#   inflating: ./data/test/410.png
#   inflating: ./data/test/411.png
#   inflating: ./data/test/412.png
#   inflating: ./data/test/413.png
#   inflating: ./data/test/414.png
#   inflating: ./data/test/415.png
#   inflating: ./data/test/416.png
#   inflating: ./data/test/417.png
#   inflating: ./data/test/418.png
#   inflating: ./data/test/419.png
#   inflating: ./data/test/420.png
#   inflating: ./data/test/421.png
#   inflating: ./data/test/422.png
#   inflating: ./data/test/423.png
#   inflating: ./data/test/424.png
#   inflating: ./data/test/425.png
#   inflating: ./data/test/426.png
#   inflating: ./data/test/427.png
#   inflating: ./data/test/428.png
#   inflating: ./data/test/429.png
#   inflating: ./data/test/430.png
#   inflating: ./data/test/431.png
#   inflating: ./data/test/432.png
#   inflating: ./data/test/433.png
#   inflating: ./data/test/434.png
#   inflating: ./data/test/435.png
#   inflating: ./data/test/436.png
#   inflating: ./data/test/437.png
#   inflating: ./data/test/438.png
#   inflating: ./data/test/439.png
#   inflating: ./data/test/440.png
#   inflating: ./data/test/441.png
#   inflating: ./data/test/442.png
#   inflating: ./data/test/443.png
#   inflating: ./data/test/444.png
#   inflating: ./data/test/445.png
#   inflating: ./data/test/446.png
#   inflating: ./data/test/447.png
#   inflating: ./data/test/448.png
#   inflating: ./data/test/449.png
#   inflating: ./data/test/450.png
#   inflating: ./data/test/451.png
#   inflating: ./data/test/452.png
#   inflating: ./data/test/453.png
#   inflating: ./data/test/454.png
#   inflating: ./data/test/455.png
#   inflating: ./data/test/456.png
#   inflating: ./data/test/457.png
#   inflating: ./data/test/458.png
#   inflating: ./data/test/459.png
#   inflating: ./data/test/460.png
#   inflating: ./data/test/461.png
#   inflating: ./data/test/462.png
#   inflating: ./data/test/463.png
#   inflating: ./data/test/464.png
#   inflating: ./data/test/465.png
#   inflating: ./data/test/466.png
#   inflating: ./data/test/467.png
#   inflating: ./data/test/468.png
#   inflating: ./data/test/469.png
#   inflating: ./data/test/470.png
#   inflating: ./data/test/471.png
#   inflating: ./data/test/472.png
#   inflating: ./data/test/473.png
#   inflating: ./data/test/474.png
#   inflating: ./data/test/475.png
#   inflating: ./data/test/476.png
#   inflating: ./data/test/477.png
#   inflating: ./data/test/478.png
#   inflating: ./data/test/479.png
#   inflating: ./data/test/480.png
#   inflating: ./data/test/481.png
#   inflating: ./data/test/482.png
#   inflating: ./data/test/483.png
#   inflating: ./data/test/484.png
#   inflating: ./data/test/485.png
#   inflating: ./data/test/486.png
#   inflating: ./data/test/487.png
#   inflating: ./data/test/488.png
#   inflating: ./data/test/489.png
#   inflating: ./data/test/490.png
#   inflating: ./data/test/491.png
#   inflating: ./data/test/492.png
#   inflating: ./data/test/493.png
#   inflating: ./data/test/494.png
#   inflating: ./data/test/495.png
#   inflating: ./data/test/496.png
#   inflating: ./data/test/497.png
#   inflating: ./data/test/498.png
#   inflating: ./data/test/499.png
#   inflating: ./data/test/500.png
#   inflating: ./data/test/501.png
#   inflating: ./data/test/502.png
#   inflating: ./data/test/503.png
#   inflating: ./data/test/504.png
#   inflating: ./data/test/505.png
#   inflating: ./data/test/506.png
#   inflating: ./data/test/507.png
#   inflating: ./data/test/508.png
#   inflating: ./data/test/509.png
#   inflating: ./data/test/510.png
#   inflating: ./data/test/511.png
#   inflating: ./data/test/512.png
#   inflating: ./data/test/513.png
#   inflating: ./data/test/514.png
#   inflating: ./data/test/515.png
#   inflating: ./data/test/516.png
#   inflating: ./data/test/517.png
#   inflating: ./data/test/518.png
#   inflating: ./data/test/519.png
#   inflating: ./data/test/520.png
#   inflating: ./data/test/521.png
#   inflating: ./data/test/522.png
#   inflating: ./data/test/523.png
#   inflating: ./data/test/524.png
#   inflating: ./data/test/525.png
#   inflating: ./data/test/526.png
#   inflating: ./data/test/527.png
#   inflating: ./data/test/528.png
#   inflating: ./data/test/529.png
#   inflating: ./data/test/530.png
#   inflating: ./data/test/531.png
#   inflating: ./data/test/532.png
#   inflating: ./data/test/533.png
#   inflating: ./data/test/534.png
#   inflating: ./data/test/535.png
#   inflating: ./data/test/536.png
#   inflating: ./data/test/537.png
#   inflating: ./data/test/538.png
#   inflating: ./data/test/539.png
#   inflating: ./data/test/540.png
#   inflating: ./data/test/541.png
#   inflating: ./data/test/542.png
#   inflating: ./data/test/543.png
#   inflating: ./data/test/544.png
#   inflating: ./data/test/545.png
#   inflating: ./data/test/546.png
#   inflating: ./data/test/547.png
#   inflating: ./data/test/548.png
#   inflating: ./data/test/549.png
#   inflating: ./data/test/550.png
#   inflating: ./data/test/551.png
#   inflating: ./data/test/552.png
#   inflating: ./data/test/553.png
#   inflating: ./data/test/554.png
#   inflating: ./data/test/555.png
#   inflating: ./data/test/556.png
#   inflating: ./data/test/557.png
#   inflating: ./data/test/558.png
#   inflating: ./data/test/559.png
#   inflating: ./data/test/560.png
#   inflating: ./data/test/561.png
#   inflating: ./data/test/562.png
#   inflating: ./data/test/563.png
#   inflating: ./data/test/564.png
#   inflating: ./data/test/565.png
#   inflating: ./data/test/566.png
#   inflating: ./data/test/567.png
#   inflating: ./data/test/568.png
#   inflating: ./data/test/569.png
#   inflating: ./data/test/570.png
#   inflating: ./data/test/571.png
#   inflating: ./data/test/572.png
#   inflating: ./data/test/573.png
#   inflating: ./data/test/574.png
#   inflating: ./data/test/575.png
#   inflating: ./data/test/576.png
#   inflating: ./data/test/577.png
#   inflating: ./data/test/578.png
#   inflating: ./data/test/579.png
#   inflating: ./data/test/580.png
#   inflating: ./data/test/581.png
#   inflating: ./data/test/582.png
#   inflating: ./data/test/583.png
#   inflating: ./data/test/584.png
#   inflating: ./data/test/585.png
#   inflating: ./data/test/586.png
#   inflating: ./data/test/587.png
#   inflating: ./data/test/588.png
#   inflating: ./data/test/589.png
#   inflating: ./data/test/590.png
#   inflating: ./data/test/591.png
#   inflating: ./data/test/592.png
#   inflating: ./data/test/593.png
#   inflating: ./data/test/594.png
#   inflating: ./data/test/595.png
#   inflating: ./data/test/596.png
#   inflating: ./data/test/597.png
#   inflating: ./data/test/598.png
#   inflating: ./data/test/599.png
#   inflating: ./data/test/600.png
#   inflating: ./data/test/601.png
#   inflating: ./data/test/602.png
#   inflating: ./data/test/603.png
#   inflating: ./data/test/604.png
#   inflating: ./data/test/605.png
#   inflating: ./data/test/606.png
#   inflating: ./data/test/607.png
#   inflating: ./data/test/608.png
#   inflating: ./data/test/609.png
#   inflating: ./data/test/610.png
#   inflating: ./data/test/611.png
#   inflating: ./data/test/612.png
#   inflating: ./data/test/613.png
#   inflating: ./data/test/614.png
#   inflating: ./data/test/615.png
#   inflating: ./data/test/616.png
#   inflating: ./data/test/617.png
#   inflating: ./data/test/618.png
#   inflating: ./data/test/619.png
#   inflating: ./data/test/620.png
#   inflating: ./data/test/621.png
#   inflating: ./data/test/622.png
#   inflating: ./data/test/623.png
#   inflating: ./data/test/624.png
#   inflating: ./data/test/625.png
#   inflating: ./data/test/626.png
#   inflating: ./data/test/627.png
#   inflating: ./data/test/628.png
#   inflating: ./data/test/629.png
#   inflating: ./data/test/630.png
#   inflating: ./data/test/631.png
#   inflating: ./data/test/632.png
#   inflating: ./data/test/633.png
#   inflating: ./data/test/634.png
#   inflating: ./data/test/635.png
#   inflating: ./data/test/636.png
#   inflating: ./data/test/637.png
#   inflating: ./data/test/638.png
#   inflating: ./data/test/639.png
#   inflating: ./data/test/640.png
#   inflating: ./data/test/641.png
#   inflating: ./data/test/642.png
#   inflating: ./data/test/643.png
#   inflating: ./data/test/644.png
#   inflating: ./data/test/645.png
#   inflating: ./data/test/646.png
#   inflating: ./data/test/647.png
#   inflating: ./data/test/648.png
#   inflating: ./data/test/649.png
#   inflating: ./data/test/650.png
#   inflating: ./data/test/651.png
#   inflating: ./data/test/652.png
#   inflating: ./data/test/653.png
#   inflating: ./data/test/654.png
#   inflating: ./data/test/655.png
#   inflating: ./data/test/656.png
#   inflating: ./data/test/657.png
#   inflating: ./data/test/658.png
#   inflating: ./data/test/659.png
#   inflating: ./data/test/660.png
#   inflating: ./data/test/661.png
#   inflating: ./data/test/662.png
#   inflating: ./data/test/663.png
#   inflating: ./data/test/664.png
#   inflating: ./data/test/665.png
#   inflating: ./data/test/666.png
#   inflating: ./data/test/667.png
#   inflating: ./data/test/668.png
#   inflating: ./data/test/669.png
#   inflating: ./data/test/670.png
#   inflating: ./data/test/671.png
#   inflating: ./data/test/672.png
#   inflating: ./data/test/673.png
#   inflating: ./data/test/674.png
#   inflating: ./data/test/675.png
#   inflating: ./data/test/676.png
#   inflating: ./data/test/677.png
#   inflating: ./data/test/678.png
#   inflating: ./data/test/679.png
#   inflating: ./data/test/680.png
#   inflating: ./data/test/681.png
#   inflating: ./data/test/682.png
#   inflating: ./data/test/683.png
#   inflating: ./data/test/684.png
#   inflating: ./data/test/685.png
#   inflating: ./data/test/686.png
#   inflating: ./data/test/687.png
#   inflating: ./data/test/688.png
#   inflating: ./data/test/689.png
#   inflating: ./data/test/690.png
#   inflating: ./data/test/691.png
#   inflating: ./data/test/692.png
#   inflating: ./data/test/693.png
#   inflating: ./data/test/694.png
#   inflating: ./data/test/695.png
#   inflating: ./data/test/696.png
#   inflating: ./data/test/697.png
#   inflating: ./data/test/698.png
#   inflating: ./data/test/699.png
#   inflating: ./data/test/700.png
#   inflating: ./data/test/701.png
#   inflating: ./data/test/702.png
#   inflating: ./data/test/703.png
#   inflating: ./data/test/704.png
#   inflating: ./data/test/705.png
#   inflating: ./data/test/706.png
#   inflating: ./data/test/707.png
#   inflating: ./data/test/708.png
#   inflating: ./data/test/709.png
#   inflating: ./data/test/710.png
#   inflating: ./data/test/711.png
#   inflating: ./data/test/712.png
#   inflating: ./data/test/713.png
#   inflating: ./data/test/714.png
#   inflating: ./data/test/715.png
#   inflating: ./data/test/716.png
#   inflating: ./data/test/717.png
#   inflating: ./data/test/718.png
#   inflating: ./data/test/719.png
#   inflating: ./data/test/720.png
#   inflating: ./data/test/721.png
#   inflating: ./data/test/722.png
#   inflating: ./data/test/723.png
#   inflating: ./data/test/724.png
#   inflating: ./data/test/725.png
#   inflating: ./data/test/726.png
#   inflating: ./data/test/727.png
#   inflating: ./data/test/728.png
#   inflating: ./data/test/729.png
#   inflating: ./data/test/730.png
#   inflating: ./data/test/731.png
#   inflating: ./data/test/732.png
#   inflating: ./data/test/733.png
#   inflating: ./data/test/734.png
#   inflating: ./data/test/735.png
#   inflating: ./data/test/736.png
#   inflating: ./data/test/737.png
#   inflating: ./data/test/738.png
#   inflating: ./data/test/739.png
#   inflating: ./data/test/740.png
#   inflating: ./data/test/741.png
#   inflating: ./data/test/742.png
#   inflating: ./data/test/743.png
#   inflating: ./data/test/744.png
#   inflating: ./data/test/745.png
#   inflating: ./data/test/746.png
#   inflating: ./data/test/747.png
#   inflating: ./data/test/748.png
#   inflating: ./data/test/749.png
#   inflating: ./data/test/750.png
#   inflating: ./data/test/751.png
#   inflating: ./data/test/752.png
#   inflating: ./data/test/753.png
#   inflating: ./data/test/754.png
#   inflating: ./data/test/755.png
#   inflating: ./data/test/756.png
#   inflating: ./data/test/757.png
#   inflating: ./data/test/758.png
#   inflating: ./data/test/759.png
#   inflating: ./data/test/760.png
#   inflating: ./data/test/761.png
#   inflating: ./data/test/762.png
#   inflating: ./data/test/763.png
#   inflating: ./data/test/764.png
#   inflating: ./data/test/765.png
#   inflating: ./data/test/766.png
#   inflating: ./data/test/767.png
#   inflating: ./data/test/768.png
#   inflating: ./data/test/769.png
#   inflating: ./data/test/770.png
#   inflating: ./data/test/771.png
#   inflating: ./data/test/772.png
#   inflating: ./data/test/773.png
#   inflating: ./data/test/774.png
#   inflating: ./data/test/775.png
#   inflating: ./data/test/776.png
#   inflating: ./data/test/777.png
#   inflating: ./data/test/778.png
#   inflating: ./data/test/779.png
#   inflating: ./data/test/780.png
#   inflating: ./data/test/781.png
#   inflating: ./data/test/782.png
#   inflating: ./data/test/783.png
#   inflating: ./data/test/784.png
#   inflating: ./data/test/785.png
#   inflating: ./data/test/786.png
#   inflating: ./data/test/787.png
#   inflating: ./data/test/788.png
#   inflating: ./data/test/789.png
#   inflating: ./data/test/790.png
#   inflating: ./data/test/791.png
#    creating: ./data/train/
#    creating: ./data/train/가구수정/
#   inflating: ./data/train/가구수정/0.png
#   inflating: ./data/train/가구수정/1.png
#   inflating: ./data/train/가구수정/10.png
#   inflating: ./data/train/가구수정/11.png
#   inflating: ./data/train/가구수정/2.png
#   inflating: ./data/train/가구수정/3.png
#   inflating: ./data/train/가구수정/4.png
#   inflating: ./data/train/가구수정/5.png
#   inflating: ./data/train/가구수정/6.png
#   inflating: ./data/train/가구수정/7.png
#   inflating: ./data/train/가구수정/8.png
#   inflating: ./data/train/가구수정/9.png
#    creating: ./data/train/걸레받이수정/
#   inflating: ./data/train/걸레받이수정/0.png
#   inflating: ./data/train/걸레받이수정/1.png
#   inflating: ./data/train/걸레받이수정/10.png
#   inflating: ./data/train/걸레받이수정/100.png
#   inflating: ./data/train/걸레받이수정/101.png
#   inflating: ./data/train/걸레받이수정/102.png
#   inflating: ./data/train/걸레받이수정/103.png
#   inflating: ./data/train/걸레받이수정/104.png
#   inflating: ./data/train/걸레받이수정/105.png
#   inflating: ./data/train/걸레받이수정/106.png
#   inflating: ./data/train/걸레받이수정/107.png
#   inflating: ./data/train/걸레받이수정/108.png
#   inflating: ./data/train/걸레받이수정/109.png
#   inflating: ./data/train/걸레받이수정/11.png
#   inflating: ./data/train/걸레받이수정/110.png
#   inflating: ./data/train/걸레받이수정/111.png
#   inflating: ./data/train/걸레받이수정/112.png
#   inflating: ./data/train/걸레받이수정/113.png
#   inflating: ./data/train/걸레받이수정/114.png
#   inflating: ./data/train/걸레받이수정/115.png
#   inflating: ./data/train/걸레받이수정/116.png
#   inflating: ./data/train/걸레받이수정/117.png
#   inflating: ./data/train/걸레받이수정/118.png
#   inflating: ./data/train/걸레받이수정/119.png
#   inflating: ./data/train/걸레받이수정/12.png
#   inflating: ./data/train/걸레받이수정/120.png
#   inflating: ./data/train/걸레받이수정/121.png
#   inflating: ./data/train/걸레받이수정/122.png
#   inflating: ./data/train/걸레받이수정/123.png
#   inflating: ./data/train/걸레받이수정/124.png
#   inflating: ./data/train/걸레받이수정/125.png
#   inflating: ./data/train/걸레받이수정/126.png
#   inflating: ./data/train/걸레받이수정/127.png
#   inflating: ./data/train/걸레받이수정/128.png
#   inflating: ./data/train/걸레받이수정/129.png
#   inflating: ./data/train/걸레받이수정/13.png
#   inflating: ./data/train/걸레받이수정/130.png
#   inflating: ./data/train/걸레받이수정/131.png
#   inflating: ./data/train/걸레받이수정/132.png
#   inflating: ./data/train/걸레받이수정/133.png
#   inflating: ./data/train/걸레받이수정/134.png
#   inflating: ./data/train/걸레받이수정/135.png
#   inflating: ./data/train/걸레받이수정/136.png
#   inflating: ./data/train/걸레받이수정/137.png
#   inflating: ./data/train/걸레받이수정/138.png
#   inflating: ./data/train/걸레받이수정/139.png
#   inflating: ./data/train/걸레받이수정/14.png
#   inflating: ./data/train/걸레받이수정/140.png
#   inflating: ./data/train/걸레받이수정/141.png
#   inflating: ./data/train/걸레받이수정/142.png
#   inflating: ./data/train/걸레받이수정/143.png
#   inflating: ./data/train/걸레받이수정/144.png
#   inflating: ./data/train/걸레받이수정/145.png
#   inflating: ./data/train/걸레받이수정/146.png
#   inflating: ./data/train/걸레받이수정/147.png
#   inflating: ./data/train/걸레받이수정/148.png
#   inflating: ./data/train/걸레받이수정/149.png
#   inflating: ./data/train/걸레받이수정/15.png
#   inflating: ./data/train/걸레받이수정/150.png
#   inflating: ./data/train/걸레받이수정/151.png
#   inflating: ./data/train/걸레받이수정/152.png
#   inflating: ./data/train/걸레받이수정/153.png
#   inflating: ./data/train/걸레받이수정/154.png
#   inflating: ./data/train/걸레받이수정/155.png
#   inflating: ./data/train/걸레받이수정/156.png
#   inflating: ./data/train/걸레받이수정/157.png
#   inflating: ./data/train/걸레받이수정/158.png
#   inflating: ./data/train/걸레받이수정/159.png
#   inflating: ./data/train/걸레받이수정/16.png
#   inflating: ./data/train/걸레받이수정/160.png
#   inflating: ./data/train/걸레받이수정/161.png
#   inflating: ./data/train/걸레받이수정/162.png
#   inflating: ./data/train/걸레받이수정/163.png
#   inflating: ./data/train/걸레받이수정/164.png
#   inflating: ./data/train/걸레받이수정/165.png
#   inflating: ./data/train/걸레받이수정/166.png
#   inflating: ./data/train/걸레받이수정/167.png
#   inflating: ./data/train/걸레받이수정/168.png
#   inflating: ./data/train/걸레받이수정/169.png
#   inflating: ./data/train/걸레받이수정/17.png
#   inflating: ./data/train/걸레받이수정/170.png
#   inflating: ./data/train/걸레받이수정/171.png
#   inflating: ./data/train/걸레받이수정/172.png
#   inflating: ./data/train/걸레받이수정/173.png
#   inflating: ./data/train/걸레받이수정/174.png
#   inflating: ./data/train/걸레받이수정/175.png
#   inflating: ./data/train/걸레받이수정/176.png
#   inflating: ./data/train/걸레받이수정/177.png
#   inflating: ./data/train/걸레받이수정/178.png
#   inflating: ./data/train/걸레받이수정/179.png
#   inflating: ./data/train/걸레받이수정/18.png
#   inflating: ./data/train/걸레받이수정/180.png
#   inflating: ./data/train/걸레받이수정/181.png
#   inflating: ./data/train/걸레받이수정/182.png
#   inflating: ./data/train/걸레받이수정/183.png
#   inflating: ./data/train/걸레받이수정/184.png
#   inflating: ./data/train/걸레받이수정/185.png
#   inflating: ./data/train/걸레받이수정/186.png
#   inflating: ./data/train/걸레받이수정/187.png
#   inflating: ./data/train/걸레받이수정/188.png
#   inflating: ./data/train/걸레받이수정/189.png
#   inflating: ./data/train/걸레받이수정/19.png
#   inflating: ./data/train/걸레받이수정/190.png
#   inflating: ./data/train/걸레받이수정/191.png
#   inflating: ./data/train/걸레받이수정/192.png
#   inflating: ./data/train/걸레받이수정/193.png
#   inflating: ./data/train/걸레받이수정/194.png
#   inflating: ./data/train/걸레받이수정/195.png
#   inflating: ./data/train/걸레받이수정/196.png
#   inflating: ./data/train/걸레받이수정/197.png
#   inflating: ./data/train/걸레받이수정/198.png
#   inflating: ./data/train/걸레받이수정/199.png
#   inflating: ./data/train/걸레받이수정/2.png
#   inflating: ./data/train/걸레받이수정/20.png
#   inflating: ./data/train/걸레받이수정/200.png
#   inflating: ./data/train/걸레받이수정/201.png
#   inflating: ./data/train/걸레받이수정/202.png
#   inflating: ./data/train/걸레받이수정/203.png
#   inflating: ./data/train/걸레받이수정/204.png
#   inflating: ./data/train/걸레받이수정/205.png
#   inflating: ./data/train/걸레받이수정/206.png
#   inflating: ./data/train/걸레받이수정/207.png
#   inflating: ./data/train/걸레받이수정/208.png
#   inflating: ./data/train/걸레받이수정/209.png
#   inflating: ./data/train/걸레받이수정/21.png
#   inflating: ./data/train/걸레받이수정/210.png
#   inflating: ./data/train/걸레받이수정/211.png
#   inflating: ./data/train/걸레받이수정/212.png
#   inflating: ./data/train/걸레받이수정/213.png
#   inflating: ./data/train/걸레받이수정/214.png
#   inflating: ./data/train/걸레받이수정/215.png
#   inflating: ./data/train/걸레받이수정/216.png
#   inflating: ./data/train/걸레받이수정/217.png
#   inflating: ./data/train/걸레받이수정/218.png
#   inflating: ./data/train/걸레받이수정/219.png
#   inflating: ./data/train/걸레받이수정/22.png
#   inflating: ./data/train/걸레받이수정/220.png
#   inflating: ./data/train/걸레받이수정/221.png
#   inflating: ./data/train/걸레받이수정/222.png
#   inflating: ./data/train/걸레받이수정/223.png
#   inflating: ./data/train/걸레받이수정/224.png
#   inflating: ./data/train/걸레받이수정/225.png
#   inflating: ./data/train/걸레받이수정/226.png
#   inflating: ./data/train/걸레받이수정/227.png
#   inflating: ./data/train/걸레받이수정/228.png
#   inflating: ./data/train/걸레받이수정/229.png
#   inflating: ./data/train/걸레받이수정/23.png
#   inflating: ./data/train/걸레받이수정/230.png
#   inflating: ./data/train/걸레받이수정/231.png
#   inflating: ./data/train/걸레받이수정/232.png
#   inflating: ./data/train/걸레받이수정/233.png
#   inflating: ./data/train/걸레받이수정/234.png
#   inflating: ./data/train/걸레받이수정/235.png
#   inflating: ./data/train/걸레받이수정/236.png
#   inflating: ./data/train/걸레받이수정/237.png
#   inflating: ./data/train/걸레받이수정/238.png
#   inflating: ./data/train/걸레받이수정/239.png
#   inflating: ./data/train/걸레받이수정/24.png
#   inflating: ./data/train/걸레받이수정/240.png
#   inflating: ./data/train/걸레받이수정/241.png
#   inflating: ./data/train/걸레받이수정/242.png
#   inflating: ./data/train/걸레받이수정/243.png
#   inflating: ./data/train/걸레받이수정/244.png
#   inflating: ./data/train/걸레받이수정/245.png
#   inflating: ./data/train/걸레받이수정/246.png
#   inflating: ./data/train/걸레받이수정/247.png
#   inflating: ./data/train/걸레받이수정/248.png
#   inflating: ./data/train/걸레받이수정/249.png
#   inflating: ./data/train/걸레받이수정/25.png
#   inflating: ./data/train/걸레받이수정/250.png
#   inflating: ./data/train/걸레받이수정/251.png
#   inflating: ./data/train/걸레받이수정/252.png
#   inflating: ./data/train/걸레받이수정/253.png
#   inflating: ./data/train/걸레받이수정/254.png
#   inflating: ./data/train/걸레받이수정/255.png
#   inflating: ./data/train/걸레받이수정/256.png
#   inflating: ./data/train/걸레받이수정/257.png
#   inflating: ./data/train/걸레받이수정/258.png
#   inflating: ./data/train/걸레받이수정/259.png
#   inflating: ./data/train/걸레받이수정/26.png
#   inflating: ./data/train/걸레받이수정/260.png
#   inflating: ./data/train/걸레받이수정/261.png
#   inflating: ./data/train/걸레받이수정/262.png
#   inflating: ./data/train/걸레받이수정/263.png
#   inflating: ./data/train/걸레받이수정/264.png
#   inflating: ./data/train/걸레받이수정/265.png
#   inflating: ./data/train/걸레받이수정/266.png
#   inflating: ./data/train/걸레받이수정/267.png
#   inflating: ./data/train/걸레받이수정/268.png
#   inflating: ./data/train/걸레받이수정/269.png
#   inflating: ./data/train/걸레받이수정/27.png
#   inflating: ./data/train/걸레받이수정/270.png
#   inflating: ./data/train/걸레받이수정/271.png
#   inflating: ./data/train/걸레받이수정/272.png
#   inflating: ./data/train/걸레받이수정/273.png
#   inflating: ./data/train/걸레받이수정/274.png
#   inflating: ./data/train/걸레받이수정/275.png
#   inflating: ./data/train/걸레받이수정/276.png
#   inflating: ./data/train/걸레받이수정/277.png
#   inflating: ./data/train/걸레받이수정/278.png
#   inflating: ./data/train/걸레받이수정/279.png
#   inflating: ./data/train/걸레받이수정/28.png
#   inflating: ./data/train/걸레받이수정/280.png
#   inflating: ./data/train/걸레받이수정/281.png
#   inflating: ./data/train/걸레받이수정/282.png
#   inflating: ./data/train/걸레받이수정/283.png
#   inflating: ./data/train/걸레받이수정/284.png
#   inflating: ./data/train/걸레받이수정/285.png
#   inflating: ./data/train/걸레받이수정/286.png
#   inflating: ./data/train/걸레받이수정/287.png
#   inflating: ./data/train/걸레받이수정/288.png
#   inflating: ./data/train/걸레받이수정/289.png
#   inflating: ./data/train/걸레받이수정/29.png
#   inflating: ./data/train/걸레받이수정/290.png
#   inflating: ./data/train/걸레받이수정/291.png
#   inflating: ./data/train/걸레받이수정/292.png
#   inflating: ./data/train/걸레받이수정/293.png
#   inflating: ./data/train/걸레받이수정/294.png
#   inflating: ./data/train/걸레받이수정/295.png
#   inflating: ./data/train/걸레받이수정/296.png
#   inflating: ./data/train/걸레받이수정/297.png
#   inflating: ./data/train/걸레받이수정/298.png
#   inflating: ./data/train/걸레받이수정/299.png
#   inflating: ./data/train/걸레받이수정/3.png
#   inflating: ./data/train/걸레받이수정/30.png
#   inflating: ./data/train/걸레받이수정/300.png
#   inflating: ./data/train/걸레받이수정/301.png
#   inflating: ./data/train/걸레받이수정/302.png
#   inflating: ./data/train/걸레받이수정/303.png
#   inflating: ./data/train/걸레받이수정/304.png
#   inflating: ./data/train/걸레받이수정/305.png
#   inflating: ./data/train/걸레받이수정/306.png
#   inflating: ./data/train/걸레받이수정/31.png
#   inflating: ./data/train/걸레받이수정/32.png
#   inflating: ./data/train/걸레받이수정/33.png
#   inflating: ./data/train/걸레받이수정/34.png
#   inflating: ./data/train/걸레받이수정/35.png
#   inflating: ./data/train/걸레받이수정/36.png
#   inflating: ./data/train/걸레받이수정/37.png
#   inflating: ./data/train/걸레받이수정/38.png
#   inflating: ./data/train/걸레받이수정/39.png
#   inflating: ./data/train/걸레받이수정/4.png
#   inflating: ./data/train/걸레받이수정/40.png
#   inflating: ./data/train/걸레받이수정/41.png
#   inflating: ./data/train/걸레받이수정/42.png
#   inflating: ./data/train/걸레받이수정/43.png
#   inflating: ./data/train/걸레받이수정/44.png
#   inflating: ./data/train/걸레받이수정/45.png
#   inflating: ./data/train/걸레받이수정/46.png
#   inflating: ./data/train/걸레받이수정/47.png
#   inflating: ./data/train/걸레받이수정/48.png
#   inflating: ./data/train/걸레받이수정/49.png
#   inflating: ./data/train/걸레받이수정/5.png
#   inflating: ./data/train/걸레받이수정/50.png
#   inflating: ./data/train/걸레받이수정/51.png
#   inflating: ./data/train/걸레받이수정/52.png
#   inflating: ./data/train/걸레받이수정/53.png
#   inflating: ./data/train/걸레받이수정/54.png
#   inflating: ./data/train/걸레받이수정/55.png
#   inflating: ./data/train/걸레받이수정/56.png
#   inflating: ./data/train/걸레받이수정/57.png
#   inflating: ./data/train/걸레받이수정/58.png
#   inflating: ./data/train/걸레받이수정/59.png
#   inflating: ./data/train/걸레받이수정/6.png
#   inflating: ./data/train/걸레받이수정/60.png
#   inflating: ./data/train/걸레받이수정/61.png
#   inflating: ./data/train/걸레받이수정/62.png
#   inflating: ./data/train/걸레받이수정/63.png
#   inflating: ./data/train/걸레받이수정/64.png
#   inflating: ./data/train/걸레받이수정/65.png
#   inflating: ./data/train/걸레받이수정/66.png
#   inflating: ./data/train/걸레받이수정/67.png
#   inflating: ./data/train/걸레받이수정/68.png
#   inflating: ./data/train/걸레받이수정/69.png
#   inflating: ./data/train/걸레받이수정/7.png
#   inflating: ./data/train/걸레받이수정/70.png
#   inflating: ./data/train/걸레받이수정/71.png
#   inflating: ./data/train/걸레받이수정/72.png
#   inflating: ./data/train/걸레받이수정/73.png
#   inflating: ./data/train/걸레받이수정/74.png
#   inflating: ./data/train/걸레받이수정/75.png
#   inflating: ./data/train/걸레받이수정/76.png
#   inflating: ./data/train/걸레받이수정/77.png
#   inflating: ./data/train/걸레받이수정/78.png
#   inflating: ./data/train/걸레받이수정/79.png
#   inflating: ./data/train/걸레받이수정/8.png
#   inflating: ./data/train/걸레받이수정/80.png
#   inflating: ./data/train/걸레받이수정/81.png
#   inflating: ./data/train/걸레받이수정/82.png
#   inflating: ./data/train/걸레받이수정/83.png
#   inflating: ./data/train/걸레받이수정/84.png
#   inflating: ./data/train/걸레받이수정/85.png
#   inflating: ./data/train/걸레받이수정/86.png
#   inflating: ./data/train/걸레받이수정/87.png
#   inflating: ./data/train/걸레받이수정/88.png
#   inflating: ./data/train/걸레받이수정/89.png
#   inflating: ./data/train/걸레받이수정/9.png
#   inflating: ./data/train/걸레받이수정/90.png
#   inflating: ./data/train/걸레받이수정/91.png
#   inflating: ./data/train/걸레받이수정/92.png
#   inflating: ./data/train/걸레받이수정/93.png
#   inflating: ./data/train/걸레받이수정/94.png
#   inflating: ./data/train/걸레받이수정/95.png
#   inflating: ./data/train/걸레받이수정/96.png
#   inflating: ./data/train/걸레받이수정/97.png
#   inflating: ./data/train/걸레받이수정/98.png
#   inflating: ./data/train/걸레받이수정/99.png
#    creating: ./data/train/곰팡이/
#   inflating: ./data/train/곰팡이/0.png
#   inflating: ./data/train/곰팡이/1.png
#   inflating: ./data/train/곰팡이/10.png
#   inflating: ./data/train/곰팡이/100.png
#   inflating: ./data/train/곰팡이/101.png
#   inflating: ./data/train/곰팡이/102.png
#   inflating: ./data/train/곰팡이/103.png
#   inflating: ./data/train/곰팡이/104.png
#   inflating: ./data/train/곰팡이/105.png
#   inflating: ./data/train/곰팡이/106.png
#   inflating: ./data/train/곰팡이/107.png
#   inflating: ./data/train/곰팡이/108.png
#   inflating: ./data/train/곰팡이/109.png
#   inflating: ./data/train/곰팡이/11.png
#   inflating: ./data/train/곰팡이/110.png
#   inflating: ./data/train/곰팡이/111.png
#   inflating: ./data/train/곰팡이/112.png
#   inflating: ./data/train/곰팡이/113.png
#   inflating: ./data/train/곰팡이/114.png
#   inflating: ./data/train/곰팡이/115.png
#   inflating: ./data/train/곰팡이/116.png
#   inflating: ./data/train/곰팡이/117.png
#   inflating: ./data/train/곰팡이/118.png
#   inflating: ./data/train/곰팡이/119.png
#   inflating: ./data/train/곰팡이/12.png
#   inflating: ./data/train/곰팡이/120.png
#   inflating: ./data/train/곰팡이/121.png
#   inflating: ./data/train/곰팡이/122.png
#   inflating: ./data/train/곰팡이/123.png
#   inflating: ./data/train/곰팡이/124.png
#   inflating: ./data/train/곰팡이/125.png
#   inflating: ./data/train/곰팡이/126.png
#   inflating: ./data/train/곰팡이/127.png
#   inflating: ./data/train/곰팡이/128.png
#   inflating: ./data/train/곰팡이/129.png
#   inflating: ./data/train/곰팡이/13.png
#   inflating: ./data/train/곰팡이/130.png
#   inflating: ./data/train/곰팡이/131.png
#   inflating: ./data/train/곰팡이/132.png
#   inflating: ./data/train/곰팡이/133.png
#   inflating: ./data/train/곰팡이/134.png
#   inflating: ./data/train/곰팡이/135.png
#   inflating: ./data/train/곰팡이/136.png
#   inflating: ./data/train/곰팡이/137.png
#   inflating: ./data/train/곰팡이/138.png
#   inflating: ./data/train/곰팡이/139.png
#   inflating: ./data/train/곰팡이/14.png
#   inflating: ./data/train/곰팡이/140.png
#   inflating: ./data/train/곰팡이/141.png
#   inflating: ./data/train/곰팡이/142.png
#   inflating: ./data/train/곰팡이/143.png
#   inflating: ./data/train/곰팡이/144.png
#   inflating: ./data/train/곰팡이/15.png
#   inflating: ./data/train/곰팡이/16.png
#   inflating: ./data/train/곰팡이/17.png
#   inflating: ./data/train/곰팡이/18.png
#   inflating: ./data/train/곰팡이/19.png
#   inflating: ./data/train/곰팡이/2.png
#   inflating: ./data/train/곰팡이/20.png
#   inflating: ./data/train/곰팡이/21.png
#   inflating: ./data/train/곰팡이/22.png
#   inflating: ./data/train/곰팡이/23.png
#   inflating: ./data/train/곰팡이/24.png
#   inflating: ./data/train/곰팡이/25.png
#   inflating: ./data/train/곰팡이/26.png
#   inflating: ./data/train/곰팡이/27.png
#   inflating: ./data/train/곰팡이/28.png
#   inflating: ./data/train/곰팡이/29.png
#   inflating: ./data/train/곰팡이/3.png
#   inflating: ./data/train/곰팡이/30.png
#   inflating: ./data/train/곰팡이/31.png
#   inflating: ./data/train/곰팡이/32.png
#   inflating: ./data/train/곰팡이/33.png
#   inflating: ./data/train/곰팡이/34.png
#   inflating: ./data/train/곰팡이/35.png
#   inflating: ./data/train/곰팡이/36.png
#   inflating: ./data/train/곰팡이/37.png
#   inflating: ./data/train/곰팡이/38.png
#   inflating: ./data/train/곰팡이/39.png
#   inflating: ./data/train/곰팡이/4.png
#   inflating: ./data/train/곰팡이/40.png
#   inflating: ./data/train/곰팡이/41.png
#   inflating: ./data/train/곰팡이/42.png
#   inflating: ./data/train/곰팡이/43.png
#   inflating: ./data/train/곰팡이/44.png
#   inflating: ./data/train/곰팡이/45.png
#   inflating: ./data/train/곰팡이/46.png
#   inflating: ./data/train/곰팡이/47.png
#   inflating: ./data/train/곰팡이/48.png
#   inflating: ./data/train/곰팡이/49.png
#   inflating: ./data/train/곰팡이/5.png
#   inflating: ./data/train/곰팡이/50.png
#   inflating: ./data/train/곰팡이/51.png
#   inflating: ./data/train/곰팡이/52.png
#   inflating: ./data/train/곰팡이/53.png
#   inflating: ./data/train/곰팡이/54.png
#   inflating: ./data/train/곰팡이/55.png
#   inflating: ./data/train/곰팡이/56.png
#   inflating: ./data/train/곰팡이/57.png
#   inflating: ./data/train/곰팡이/58.png
#   inflating: ./data/train/곰팡이/59.png
#   inflating: ./data/train/곰팡이/6.png
#   inflating: ./data/train/곰팡이/60.png
# ...
#   inflating: ./data/train/훼손/629.png
#   inflating: ./data/train/훼손/63.png
#   inflating: ./data/train/훼손/630.png
#   inflating: ./data/train/훼손/631.png
#   inflating: ./data/train/훼손/632.png
#   inflating: ./data/train/훼손/633.png
#   inflating: ./data/train/훼손/634.png
#   inflating: ./data/train/훼손/635.png
#   inflating: ./data/train/훼손/636.png
#   inflating: ./data/train/훼손/637.png
#   inflating: ./data/train/훼손/638.png
#   inflating: ./data/train/훼손/639.png
#   inflating: ./data/train/훼손/64.png
#   inflating: ./data/train/훼손/640.png
#   inflating: ./data/train/훼손/641.png
#   inflating: ./data/train/훼손/642.png
#   inflating: ./data/train/훼손/643.png
#   inflating: ./data/train/훼손/644.png
#   inflating: ./data/train/훼손/645.png
#   inflating: ./data/train/훼손/646.png
#   inflating: ./data/train/훼손/647.png
#   inflating: ./data/train/훼손/648.png
#   inflating: ./data/train/훼손/649.png
#   inflating: ./data/train/훼손/65.png
#   inflating: ./data/train/훼손/650.png
#   inflating: ./data/train/훼손/651.png
#   inflating: ./data/train/훼손/652.png
#   inflating: ./data/train/훼손/653.png
#   inflating: ./data/train/훼손/654.png
#   inflating: ./data/train/훼손/655.png
#   inflating: ./data/train/훼손/656.png
#   inflating: ./data/train/훼손/657.png
#   inflating: ./data/train/훼손/658.png
#   inflating: ./data/train/훼손/659.png
#   inflating: ./data/train/훼손/66.png
#   inflating: ./data/train/훼손/660.png
#   inflating: ./data/train/훼손/661.png
#   inflating: ./data/train/훼손/662.png
#   inflating: ./data/train/훼손/663.png
#   inflating: ./data/train/훼손/664.png
#   inflating: ./data/train/훼손/665.png
#   inflating: ./data/train/훼손/666.png
#   inflating: ./data/train/훼손/667.png
#   inflating: ./data/train/훼손/668.png
#   inflating: ./data/train/훼손/669.png
#   inflating: ./data/train/훼손/67.png
#   inflating: ./data/train/훼손/670.png
#   inflating: ./data/train/훼손/671.png
#   inflating: ./data/train/훼손/672.png
#   inflating: ./data/train/훼손/673.png
#   inflating: ./data/train/훼손/674.png
#   inflating: ./data/train/훼손/675.png
#   inflating: ./data/train/훼손/676.png
#   inflating: ./data/train/훼손/677.png
#   inflating: ./data/train/훼손/678.png
#   inflating: ./data/train/훼손/679.png
#   inflating: ./data/train/훼손/68.png
#   inflating: ./data/train/훼손/680.png
#   inflating: ./data/train/훼손/681.png
#   inflating: ./data/train/훼손/682.png
#   inflating: ./data/train/훼손/683.png
#   inflating: ./data/train/훼손/684.png
#   inflating: ./data/train/훼손/685.png
#   inflating: ./data/train/훼손/686.png
#   inflating: ./data/train/훼손/687.png
#   inflating: ./data/train/훼손/688.png
#   inflating: ./data/train/훼손/689.png
#   inflating: ./data/train/훼손/69.png
#   inflating: ./data/train/훼손/690.png
#   inflating: ./data/train/훼손/691.png
#   inflating: ./data/train/훼손/692.png
#   inflating: ./data/train/훼손/693.png
#   inflating: ./data/train/훼손/694.png
#   inflating: ./data/train/훼손/695.png
#   inflating: ./data/train/훼손/696.png
#   inflating: ./data/train/훼손/697.png
#   inflating: ./data/train/훼손/698.png
#   inflating: ./data/train/훼손/699.png
#   inflating: ./data/train/훼손/7.png
#   inflating: ./data/train/훼손/70.png
#   inflating: ./data/train/훼손/700.png
#   inflating: ./data/train/훼손/701.png
#   inflating: ./data/train/훼손/702.png
#   inflating: ./data/train/훼손/703.png
#   inflating: ./data/train/훼손/704.png
#   inflating: ./data/train/훼손/705.png
#   inflating: ./data/train/훼손/706.png
#   inflating: ./data/train/훼손/707.png
#   inflating: ./data/train/훼손/708.png
#   inflating: ./data/train/훼손/709.png
#   inflating: ./data/train/훼손/71.png
#   inflating: ./data/train/훼손/710.png
#   inflating: ./data/train/훼손/711.png
#   inflating: ./data/train/훼손/712.png
#   inflating: ./data/train/훼손/713.png
#   inflating: ./data/train/훼손/714.png
#   inflating: ./data/train/훼손/715.png
#   inflating: ./data/train/훼손/716.png
#   inflating: ./data/train/훼손/717.png
#   inflating: ./data/train/훼손/718.png
#   inflating: ./data/train/훼손/719.png
#   inflating: ./data/train/훼손/72.png
#   inflating: ./data/train/훼손/720.png
#   inflating: ./data/train/훼손/721.png
#   inflating: ./data/train/훼손/722.png
#   inflating: ./data/train/훼손/723.png
#   inflating: ./data/train/훼손/724.png
#   inflating: ./data/train/훼손/725.png
#   inflating: ./data/train/훼손/726.png
#   inflating: ./data/train/훼손/727.png
#   inflating: ./data/train/훼손/728.png
#   inflating: ./data/train/훼손/729.png
#   inflating: ./data/train/훼손/73.png
#   inflating: ./data/train/훼손/730.png
#   inflating: ./data/train/훼손/731.png
#   inflating: ./data/train/훼손/732.png
#   inflating: ./data/train/훼손/733.png
#   inflating: ./data/train/훼손/734.png
#   inflating: ./data/train/훼손/735.png
#   inflating: ./data/train/훼손/736.png
#   inflating: ./data/train/훼손/737.png
#   inflating: ./data/train/훼손/738.png
#   inflating: ./data/train/훼손/739.png
#   inflating: ./data/train/훼손/74.png
#   inflating: ./data/train/훼손/740.png
#   inflating: ./data/train/훼손/741.png
#   inflating: ./data/train/훼손/742.png
#   inflating: ./data/train/훼손/743.png
#   inflating: ./data/train/훼손/744.png
#   inflating: ./data/train/훼손/745.png
#   inflating: ./data/train/훼손/746.png
#   inflating: ./data/train/훼손/747.png
#   inflating: ./data/train/훼손/748.png
#   inflating: ./data/train/훼손/749.png
#   inflating: ./data/train/훼손/75.png
#   inflating: ./data/train/훼손/750.png
#   inflating: ./data/train/훼손/751.png
#   inflating: ./data/train/훼손/752.png
#   inflating: ./data/train/훼손/753.png
#   inflating: ./data/train/훼손/754.png
#   inflating: ./data/train/훼손/755.png
#   inflating: ./data/train/훼손/756.png
#   inflating: ./data/train/훼손/757.png
#   inflating: ./data/train/훼손/758.png
#   inflating: ./data/train/훼손/759.png
#   inflating: ./data/train/훼손/76.png
#   inflating: ./data/train/훼손/760.png
#   inflating: ./data/train/훼손/761.png
#   inflating: ./data/train/훼손/762.png
#   inflating: ./data/train/훼손/763.png
#   inflating: ./data/train/훼손/764.png
#   inflating: ./data/train/훼손/765.png
#   inflating: ./data/train/훼손/766.png
#   inflating: ./data/train/훼손/767.png
#   inflating: ./data/train/훼손/768.png
#   inflating: ./data/train/훼손/769.png
#   inflating: ./data/train/훼손/77.png
#   inflating: ./data/train/훼손/770.png
#   inflating: ./data/train/훼손/771.png
#   inflating: ./data/train/훼손/772.png
#   inflating: ./data/train/훼손/773.png
#   inflating: ./data/train/훼손/774.png
#   inflating: ./data/train/훼손/775.png
#   inflating: ./data/train/훼손/776.png
#   inflating: ./data/train/훼손/777.png
#   inflating: ./data/train/훼손/778.png
#   inflating: ./data/train/훼손/779.png
#   inflating: ./data/train/훼손/78.png
#   inflating: ./data/train/훼손/780.png
#   inflating: ./data/train/훼손/781.png
#   inflating: ./data/train/훼손/782.png
#   inflating: ./data/train/훼손/783.png
#   inflating: ./data/train/훼손/784.png
#   inflating: ./data/train/훼손/785.png
#   inflating: ./data/train/훼손/786.png
#   inflating: ./data/train/훼손/787.png
#   inflating: ./data/train/훼손/788.png
#   inflating: ./data/train/훼손/789.png
#   inflating: ./data/train/훼손/79.png
#   inflating: ./data/train/훼손/790.png
#   inflating: ./data/train/훼손/791.png
#   inflating: ./data/train/훼손/792.png
#   inflating: ./data/train/훼손/793.png
#   inflating: ./data/train/훼손/794.png
#   inflating: ./data/train/훼손/795.png
#   inflating: ./data/train/훼손/796.png
#   inflating: ./data/train/훼손/797.png
#   inflating: ./data/train/훼손/798.png
#   inflating: ./data/train/훼손/799.png
#   inflating: ./data/train/훼손/8.png
#   inflating: ./data/train/훼손/80.png
#   inflating: ./data/train/훼손/800.png
#   inflating: ./data/train/훼손/801.png
#   inflating: ./data/train/훼손/802.png
#   inflating: ./data/train/훼손/803.png
#   inflating: ./data/train/훼손/804.png
#   inflating: ./data/train/훼손/805.png
#   inflating: ./data/train/훼손/806.png
#   inflating: ./data/train/훼손/807.png
#   inflating: ./data/train/훼손/808.png
#   inflating: ./data/train/훼손/809.png
#   inflating: ./data/train/훼손/81.png
#   inflating: ./data/train/훼손/810.png
#   inflating: ./data/train/훼손/811.png
#   inflating: ./data/train/훼손/812.png
#   inflating: ./data/train/훼손/813.png
#   inflating: ./data/train/훼손/814.png
#   inflating: ./data/train/훼손/815.png
#   inflating: ./data/train/훼손/816.png
#   inflating: ./data/train/훼손/817.png
#   inflating: ./data/train/훼손/818.png
#   inflating: ./data/train/훼손/819.png
#   inflating: ./data/train/훼손/82.png
#   inflating: ./data/train/훼손/820.png
#   inflating: ./data/train/훼손/821.png
#   inflating: ./data/train/훼손/822.png
#   inflating: ./data/train/훼손/823.png
#   inflating: ./data/train/훼손/824.png
#   inflating: ./data/train/훼손/825.png
#   inflating: ./data/train/훼손/826.png
#   inflating: ./data/train/훼손/827.png
#   inflating: ./data/train/훼손/828.png
#   inflating: ./data/train/훼손/829.png
#   inflating: ./data/train/훼손/83.png
#   inflating: ./data/train/훼손/830.png
#   inflating: ./data/train/훼손/831.png
#   inflating: ./data/train/훼손/832.png
#   inflating: ./data/train/훼손/833.png
#   inflating: ./data/train/훼손/834.png
#   inflating: ./data/train/훼손/835.png
#   inflating: ./data/train/훼손/836.png
#   inflating: ./data/train/훼손/837.png
#   inflating: ./data/train/훼손/838.png
#   inflating: ./data/train/훼손/839.png
#   inflating: ./data/train/훼손/84.png
#   inflating: ./data/train/훼손/840.png
#   inflating: ./data/train/훼손/841.png
#   inflating: ./data/train/훼손/842.png
#   inflating: ./data/train/훼손/843.png
#   inflating: ./data/train/훼손/844.png
#   inflating: ./data/train/훼손/845.png
#   inflating: ./data/train/훼손/846.png
#   inflating: ./data/train/훼손/847.png
#   inflating: ./data/train/훼손/848.png
#   inflating: ./data/train/훼손/849.png
#   inflating: ./data/train/훼손/85.png
#   inflating: ./data/train/훼손/850.png
#   inflating: ./data/train/훼손/851.png
#   inflating: ./data/train/훼손/852.png
#   inflating: ./data/train/훼손/853.png
#   inflating: ./data/train/훼손/854.png
#   inflating: ./data/train/훼손/855.png
#   inflating: ./data/train/훼손/856.png
#   inflating: ./data/train/훼손/857.png
#   inflating: ./data/train/훼손/858.png
#   inflating: ./data/train/훼손/859.png
#   inflating: ./data/train/훼손/86.png
#   inflating: ./data/train/훼손/860.png
#   inflating: ./data/train/훼손/861.png
#   inflating: ./data/train/훼손/862.png
#   inflating: ./data/train/훼손/863.png
#   inflating: ./data/train/훼손/864.png
#   inflating: ./data/train/훼손/865.png
#   inflating: ./data/train/훼손/866.png
#   inflating: ./data/train/훼손/867.png
#   inflating: ./data/train/훼손/868.png
#   inflating: ./data/train/훼손/869.png
#   inflating: ./data/train/훼손/87.png
#   inflating: ./data/train/훼손/870.png
#   inflating: ./data/train/훼손/871.png
#   inflating: ./data/train/훼손/872.png
#   inflating: ./data/train/훼손/873.png
#   inflating: ./data/train/훼손/874.png
#   inflating: ./data/train/훼손/875.png
#   inflating: ./data/train/훼손/876.png
#   inflating: ./data/train/훼손/877.png
#   inflating: ./data/train/훼손/878.png
#   inflating: ./data/train/훼손/879.png
#   inflating: ./data/train/훼손/88.png
#   inflating: ./data/train/훼손/880.png
#   inflating: ./data/train/훼손/881.png
#   inflating: ./data/train/훼손/882.png
#   inflating: ./data/train/훼손/883.png
#   inflating: ./data/train/훼손/884.png
#   inflating: ./data/train/훼손/885.png
#   inflating: ./data/train/훼손/886.png
#   inflating: ./data/train/훼손/887.png
#   inflating: ./data/train/훼손/888.png
#   inflating: ./data/train/훼손/889.png
#   inflating: ./data/train/훼손/89.png
#   inflating: ./data/train/훼손/890.png
#   inflating: ./data/train/훼손/891.png
#   inflating: ./data/train/훼손/892.png
#   inflating: ./data/train/훼손/893.png
#   inflating: ./data/train/훼손/894.png
#   inflating: ./data/train/훼손/895.png
#   inflating: ./data/train/훼손/896.png
#   inflating: ./data/train/훼손/897.png
#   inflating: ./data/train/훼손/898.png
#   inflating: ./data/train/훼손/899.png
#   inflating: ./data/train/훼손/9.png
#   inflating: ./data/train/훼손/90.png
#   inflating: ./data/train/훼손/900.png
#   inflating: ./data/train/훼손/901.png
#   inflating: ./data/train/훼손/902.png
#   inflating: ./data/train/훼손/903.png
#   inflating: ./data/train/훼손/904.png
#   inflating: ./data/train/훼손/905.png
#   inflating: ./data/train/훼손/906.png
#   inflating: ./data/train/훼손/907.png
#   inflating: ./data/train/훼손/908.png
#   inflating: ./data/train/훼손/909.png
#   inflating: ./data/train/훼손/91.png
#   inflating: ./data/train/훼손/910.png
#   inflating: ./data/train/훼손/911.png
#   inflating: ./data/train/훼손/912.png
#   inflating: ./data/train/훼손/913.png
#   inflating: ./data/train/훼손/914.png
#   inflating: ./data/train/훼손/915.png
#   inflating: ./data/train/훼손/916.png
#   inflating: ./data/train/훼손/917.png
#   inflating: ./data/train/훼손/918.png
#   inflating: ./data/train/훼손/919.png
#   inflating: ./data/train/훼손/92.png
#   inflating: ./data/train/훼손/920.png
#   inflating: ./data/train/훼손/921.png
#   inflating: ./data/train/훼손/922.png
#   inflating: ./data/train/훼손/923.png
#   inflating: ./data/train/훼손/924.png
#   inflating: ./data/train/훼손/925.png
#   inflating: ./data/train/훼손/926.png
#   inflating: ./data/train/훼손/927.png
#   inflating: ./data/train/훼손/928.png
#   inflating: ./data/train/훼손/929.png
#   inflating: ./data/train/훼손/93.png
#   inflating: ./data/train/훼손/930.png
#   inflating: ./data/train/훼손/931.png
#   inflating: ./data/train/훼손/932.png
#   inflating: ./data/train/훼손/933.png
#   inflating: ./data/train/훼손/934.png
#   inflating: ./data/train/훼손/935.png
#   inflating: ./data/train/훼손/936.png
#   inflating: ./data/train/훼손/937.png
#   inflating: ./data/train/훼손/938.png
#   inflating: ./data/train/훼손/939.png
#   inflating: ./data/train/훼손/94.png
#   inflating: ./data/train/훼손/940.png
#   inflating: ./data/train/훼손/941.png
#   inflating: ./data/train/훼손/942.png
#   inflating: ./data/train/훼손/943.png
#   inflating: ./data/train/훼손/944.png
#   inflating: ./data/train/훼손/945.png
#   inflating: ./data/train/훼손/946.png
#   inflating: ./data/train/훼손/947.png
#   inflating: ./data/train/훼손/948.png
#   inflating: ./data/train/훼손/949.png
#   inflating: ./data/train/훼손/95.png
#   inflating: ./data/train/훼손/950.png
#   inflating: ./data/train/훼손/951.png
#   inflating: ./data/train/훼손/952.png
#   inflating: ./data/train/훼손/953.png
#   inflating: ./data/train/훼손/954.png
#   inflating: ./data/train/훼손/955.png
#   inflating: ./data/train/훼손/956.png
#   inflating: ./data/train/훼손/957.png
#   inflating: ./data/train/훼손/958.png
#   inflating: ./data/train/훼손/959.png
#   inflating: ./data/train/훼손/96.png
#   inflating: ./data/train/훼손/960.png
#   inflating: ./data/train/훼손/961.png
#   inflating: ./data/train/훼손/962.png
#   inflating: ./data/train/훼손/963.png
#   inflating: ./data/train/훼손/964.png
#   inflating: ./data/train/훼손/965.png
#   inflating: ./data/train/훼손/966.png
#   inflating: ./data/train/훼손/967.png
#   inflating: ./data/train/훼손/968.png
#   inflating: ./data/train/훼손/969.png
#   inflating: ./data/train/훼손/97.png
#   inflating: ./data/train/훼손/970.png
#   inflating: ./data/train/훼손/971.png
#   inflating: ./data/train/훼손/972.png
#   inflating: ./data/train/훼손/973.png
#   inflating: ./data/train/훼손/974.png
#   inflating: ./data/train/훼손/975.png
#   inflating: ./data/train/훼손/976.png
#   inflating: ./data/train/훼손/977.png
#   inflating: ./data/train/훼손/978.png
#   inflating: ./data/train/훼손/979.png
#   inflating: ./data/train/훼손/98.png
#   inflating: ./data/train/훼손/980.png
#   inflating: ./data/train/훼손/981.png
#   inflating: ./data/train/훼손/982.png
#   inflating: ./data/train/훼손/983.png
#   inflating: ./data/train/훼손/984.png
#   inflating: ./data/train/훼손/985.png
#   inflating: ./data/train/훼손/986.png
#   inflating: ./data/train/훼손/987.png
#   inflating: ./data/train/훼손/988.png
#   inflating: ./data/train/훼손/989.png
#   inflating: ./data/train/훼손/99.png
#   inflating: ./data/train/훼손/990.png
#   inflating: ./data/train/훼손/991.png
#   inflating: ./data/train/훼손/992.png
#   inflating: ./data/train/훼손/993.png
#   inflating: ./data/train/훼손/994.png
#   inflating: ./data/train/훼손/995.png
#   inflating: ./data/train/훼손/996.png
#   inflating: ./data/train/훼손/997.png
#   inflating: ./data/train/훼손/998.png
#   inflating: ./data/train/훼손/999.png

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
device
# Out:
# device(type='cuda')

# %%
## Hyperparameter Setting

CFG = {
    'IMG_SIZE':224,
    'EPOCHS': 40,
    'LEARNING_RATE':3e-4,
    'BATCH_SIZE':35,
    'SEED': 41
}

# %% [markdown]
# ### **data**

# %%
# get dataset
all_img_list = glob.glob('data/train/*/*')
df = pd.DataFrame(columns=['img_path', 'label'])
df['img_path'] = all_img_list
df['label'] = df['img_path'].apply(lambda x : str(x).split('/')[2])
df
# Out:
#                          img_path      label
# 0      data/train/면불량/1.png  면불량
# 1     data/train/면불량/81.png  면불량
# 2     data/train/면불량/39.png  면불량
# 3     data/train/면불량/74.png  면불량
# 4     data/train/면불량/96.png  면불량
# ...                           ...        ...
# 3452   data/train/곰팡이/22.png   곰팡이
# 3453   data/train/곰팡이/49.png   곰팡이
# 3454   data/train/곰팡이/72.png   곰팡이
# 3455  data/train/곰팡이/120.png   곰팡이
# 3456   data/train/곰팡이/70.png   곰팡이
#
# [3457 rows x 2 columns]

# %%
# split train val dataset
train, val, _, _ = train_test_split(df, df['label'], test_size=0.2, stratify=df['label'], random_state=CFG['SEED'])

# %%
## Label-Encoding
le = preprocessing.LabelEncoder()
train['label'] = le.fit_transform(train['label'])
val['label'] = le.transform(val['label'])

# %%
## CustomDataset

class CustomDataset(Dataset):
    def __init__(self, img_path_list, label_list, transforms=None):
        self.img_path_list = img_path_list
        self.label_list = label_list
        self.transforms = transforms
        
    def __getitem__(self, index):
        img_path = self.img_path_list[index]
        
        image = Image.open(img_path)

        image = np.array(image)
        
        if self.transforms is not None:
            image = self.transforms(image=image)['image']
        
        if self.label_list is not None:
            label = self.label_list[index]
            return image, label
        else:
            return image
        
    def __len__(self):
        return len(self.img_path_list)

# %% [markdown]
# ## **Augmentation**

# %%
train_transform = A.Compose([
                            A.Resize(CFG['IMG_SIZE'],CFG['IMG_SIZE']),
                            A.HorizontalFlip(p=0.5),
                            A.RandomBrightnessContrast(p=0.5),
                            A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225), max_pixel_value=255.0, always_apply=False, p=1.0),
                            ToTensorV2()
                            ])

test_transform = A.Compose([
                            A.Resize(CFG['IMG_SIZE'],CFG['IMG_SIZE']),
                            A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225), max_pixel_value=255.0, always_apply=False, p=1.0),
                            ToTensorV2()
                            ])

# %%
#weighted sampling
a_list = train['label'].value_counts()
class_counts = train['label'].value_counts().to_list()
class_weights = [1 / a_list[i] for i in range(len(class_counts))]
num_samples = sum(class_counts)
labels_lists = train['label'].to_list()
weights = [class_weights[labels_lists[i]] for i in range(int(num_samples))]
sampler = WeightedRandomSampler(torch.DoubleTensor(weights), int(num_samples), replacement=True)

# %%
# make dataloader
train_dataset = CustomDataset(train['img_path'].values, train['label'].values, train_transform)
train_loader = DataLoader(train_dataset, batch_size = CFG['BATCH_SIZE'], sampler=sampler, shuffle=False, num_workers=2)

val_dataset = CustomDataset(val['img_path'].values, val['label'].values, test_transform)
val_loader = DataLoader(val_dataset, batch_size=CFG['BATCH_SIZE'], shuffle=False, num_workers=2)

# %% [markdown]
# ## **model**

# %%
import timm

class ConvNeXtBase(nn.Module):
    def __init__(self):
        super().__init__()
        self.model = timm.create_model("convnext_base_384_in22ft1k", pretrained=True, num_classes=19)

    def forward(self, x):
        return self.model(x)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable

class FocalLoss(nn.Module):
    def __init__(self, gamma=0, alpha=None, size_average=True):
        super(FocalLoss, self).__init__()
        self.gamma = gamma
        self.alpha = alpha
        if isinstance(alpha,(float,int)): self.alpha = torch.Tensor([alpha]*19)
        self.alpha[18] = 1-alpha
        if isinstance(alpha,list): self.alpha = torch.Tensor(alpha)
        self.size_average = size_average

    def forward(self, input, target):
        if input.dim()>2:
            input = input.view(input.size(0),input.size(1),-1)  # N,C,H,W => N,C,H*W
            input = input.transpose(1,2)    # N,C,H*W => N,H*W,C
            input = input.contiguous().view(-1,input.size(2))   # N,H*W,C => N*H*W,C
        target = target.view(-1,1)

        logpt = F.log_softmax(input)
        logpt = logpt.gather(1,target)
        logpt = logpt.view(-1)
        pt = Variable(logpt.data.exp())

        if self.alpha is not None:
            if self.alpha.type()!=input.data.type():
                self.alpha = self.alpha.type_as(input.data)
            at = self.alpha.gather(0,target.data.view(-1))
            logpt = logpt * at

        loss = -1 * (1-pt)**self.gamma * logpt
        if self.size_average: return loss.mean()
        else: return loss.sum()

# %% [markdown]
# ## **train**

# %%
## Train

def trains(model, optimizer, train_loader, val_loader, scheduler, device):
    model.to(device)
#     criterion = nn.CrossEntropyLoss(label_smoothing=0.1).to(device)
    criterion = FocalLoss(gamma=2, alpha=0.25)
    
    best_score = 0
    best_model = None
    
    for epoch in range(1, CFG['EPOCHS']+1):
        model.train()
        train_loss = []
        for imgs, labels in tqdm(iter(train_loader)):
            imgs = imgs.float().to(device)
            labels = labels.to(device)
            
            optimizer.zero_grad()
            
            output = model(imgs)
            loss = criterion(output, labels)
            
            loss.backward()
            optimizer.step()
            
            train_loss.append(loss.item())
                    
        _val_loss, _val_score = validation(model, criterion, val_loader, device)
        _train_loss = np.mean(train_loss)
        print(f'Epoch [{epoch}], Train Loss : [{_train_loss:.5f}] Val Loss : [{_val_loss:.5f}] Val Weighted F1 Score : [{_val_score:.5f}]')
       
        if scheduler is not None:
            scheduler.step(_val_score)
            
        if best_score < _val_score:
            best_score = _val_score
            best_model = model
    
    return best_model

# %%
def validation(model, criterion, val_loader, device):
    model.eval()
    val_loss = []
    preds, true_labels = [], []

    with torch.no_grad():
        for imgs, labels in tqdm(iter(val_loader)):
            imgs = imgs.float().to(device)
            labels = labels.to(device)
            
            pred = model(imgs)
            
            loss = criterion(pred, labels)
            
            preds += pred.argmax(1).detach().cpu().numpy().tolist()
            true_labels += labels.detach().cpu().numpy().tolist()
            
            val_loss.append(loss.item())
        
        _val_loss = np.mean(val_loss)
        _val_score = f1_score(true_labels, preds, average='weighted')
    
    return _val_loss, _val_score

# %% [markdown]
# # run

# %%
#init model
model = ConvNeXtBase()
# Out:
# Downloading model.safetensors:   0%|          | 0.00/354M [00:00<?, ?B/s]

# %%
optimizer = torch.optim.Adam(params = model.parameters(), lr = CFG["LEARNING_RATE"])
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=2, threshold_mode='abs', min_lr=1e-8, verbose=True)

infer_model = trains(model, optimizer, train_loader, val_loader, scheduler, device)
# Out:
#   0%|          | 0/79 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [1], Train Loss : [0.20215] Val Loss : [0.17085] Val Weighted F1 Score : [0.71370]
#   0%|          | 0/79 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [2], Train Loss : [0.05218] Val Loss : [0.15068] Val Weighted F1 Score : [0.73293]
#   0%|          | 0/79 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [3], Train Loss : [0.02825] Val Loss : [0.13911] Val Weighted F1 Score : [0.78320]
#   0%|          | 0/79 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [4], Train Loss : [0.02785] Val Loss : [0.17425] Val Weighted F1 Score : [0.76241]
#   0%|          | 0/79 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [5], Train Loss : [0.03675] Val Loss : [0.15100] Val Weighted F1 Score : [0.79466]
#   0%|          | 0/79 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [6], Train Loss : [0.02060] Val Loss : [0.15183] Val Weighted F1 Score : [0.76211]
#   0%|          | 0/79 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [7], Train Loss : [0.01723] Val Loss : [0.12447] Val Weighted F1 Score : [0.81125]
#   0%|          | 0/79 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [8], Train Loss : [0.01227] Val Loss : [0.17301] Val Weighted F1 Score : [0.80333]
#   0%|          | 0/79 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [9], Train Loss : [0.00750] Val Loss : [0.12795] Val Weighted F1 Score : [0.80365]
#   0%|          | 0/79 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10], Train Loss : [0.01032] Val Loss : [0.15617] Val Weighted F1 Score : [0.79935]
# Epoch 00010: reducing learning rate of group 0 to 1.5000e-04.
#   0%|          | 0/79 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [11], Train Loss : [0.00842] Val Loss : [0.10705] Val Weighted F1 Score : [0.82172]
#   0%|          | 0/79 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [12], Train Loss : [0.00383] Val Loss : [0.09874] Val Weighted F1 Score : [0.80989]
#   0%|          | 0/79 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [13], Train Loss : [0.00329] Val Loss : [0.09726] Val Weighted F1 Score : [0.83604]
#   0%|          | 0/79 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [14], Train Loss : [0.00286] Val Loss : [0.10725] Val Weighted F1 Score : [0.80775]
#   0%|          | 0/79 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [15], Train Loss : [0.00430] Val Loss : [0.09530] Val Weighted F1 Score : [0.82248]
#   0%|          | 0/79 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [16], Train Loss : [0.00193] Val Loss : [0.09598] Val Weighted F1 Score : [0.84335]
#   0%|          | 0/79 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [17], Train Loss : [0.00201] Val Loss : [0.09181] Val Weighted F1 Score : [0.85408]
#   0%|          | 0/79 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [18], Train Loss : [0.00111] Val Loss : [0.09492] Val Weighted F1 Score : [0.85098]
#   0%|          | 0/79 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [19], Train Loss : [0.00115] Val Loss : [0.09663] Val Weighted F1 Score : [0.84165]
#   0%|          | 0/79 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [20], Train Loss : [0.00319] Val Loss : [0.10839] Val Weighted F1 Score : [0.84097]
# Epoch 00020: reducing learning rate of group 0 to 7.5000e-05.
#   0%|          | 0/79 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [21], Train Loss : [0.00159] Val Loss : [0.10530] Val Weighted F1 Score : [0.83433]
#   0%|          | 0/79 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [22], Train Loss : [0.00078] Val Loss : [0.10737] Val Weighted F1 Score : [0.85437]
#   0%|          | 0/79 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [23], Train Loss : [0.00042] Val Loss : [0.10677] Val Weighted F1 Score : [0.84990]
#   0%|          | 0/79 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [24], Train Loss : [0.00021] Val Loss : [0.10736] Val Weighted F1 Score : [0.85172]
#   0%|          | 0/79 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [25], Train Loss : [0.00029] Val Loss : [0.10424] Val Weighted F1 Score : [0.84472]
# Epoch 00025: reducing learning rate of group 0 to 3.7500e-05.
#   0%|          | 0/79 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [26], Train Loss : [0.00157] Val Loss : [0.10255] Val Weighted F1 Score : [0.83965]
#   0%|          | 0/79 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [27], Train Loss : [0.00074] Val Loss : [0.10316] Val Weighted F1 Score : [0.85128]
#   0%|          | 0/79 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [28], Train Loss : [0.00068] Val Loss : [0.10009] Val Weighted F1 Score : [0.85226]
# Epoch 00028: reducing learning rate of group 0 to 1.8750e-05.
#   0%|          | 0/79 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [29], Train Loss : [0.00103] Val Loss : [0.09468] Val Weighted F1 Score : [0.85784]
#   0%|          | 0/79 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [30], Train Loss : [0.00025] Val Loss : [0.09539] Val Weighted F1 Score : [0.85660]
#   0%|          | 0/79 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [31], Train Loss : [0.00026] Val Loss : [0.09543] Val Weighted F1 Score : [0.85350]
#   0%|          | 0/79 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [32], Train Loss : [0.00021] Val Loss : [0.09692] Val Weighted F1 Score : [0.85090]
# Epoch 00032: reducing learning rate of group 0 to 9.3750e-06.
#   0%|          | 0/79 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [33], Train Loss : [0.00048] Val Loss : [0.09718] Val Weighted F1 Score : [0.85023]
#   0%|          | 0/79 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [34], Train Loss : [0.00034] Val Loss : [0.09721] Val Weighted F1 Score : [0.84586]
#   0%|          | 0/79 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [35], Train Loss : [0.00068] Val Loss : [0.09681] Val Weighted F1 Score : [0.84762]
# Epoch 00035: reducing learning rate of group 0 to 4.6875e-06.
#   0%|          | 0/79 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [36], Train Loss : [0.00034] Val Loss : [0.09725] Val Weighted F1 Score : [0.85054]
#   0%|          | 0/79 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [37], Train Loss : [0.00022] Val Loss : [0.09719] Val Weighted F1 Score : [0.85054]
#   0%|          | 0/79 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [38], Train Loss : [0.00026] Val Loss : [0.09713] Val Weighted F1 Score : [0.84921]
# Epoch 00038: reducing learning rate of group 0 to 2.3437e-06.
#   0%|          | 0/79 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [39], Train Loss : [0.00026] Val Loss : [0.09723] Val Weighted F1 Score : [0.84921]
#   0%|          | 0/79 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [40], Train Loss : [0.00014] Val Loss : [0.09720] Val Weighted F1 Score : [0.84921]

# %%
preds = []
true = []
inference_loader = DataLoader(train_dataset, batch_size = CFG['BATCH_SIZE'], shuffle=False, num_workers=2)
with torch.no_grad() :
    for img, label in inference_loader :
        img = img.float().to(device)
        label = label.to(device)
        pred = infer_model(img)
        
        preds.extend(pred.argmax(1).detach().cpu().numpy())
        true.extend(label.detach().cpu().numpy().tolist())

# %%
from sklearn.metrics import confusion_matrix

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(confusion_matrix(true, preds), annot=True, vmax = 10, vmin=0, cbar=False)
plt.show()

# %%
train['pred'] = preds
train['true'] = true

# %%
train.head()
# Out:
#                        img_path  label  pred  true
# 963   data/train/훼손/1297.png     18    18    18
# 1043  data/train/훼손/1079.png     18    18    18
# 1442   data/train/훼손/828.png     18    18    18
# 1833   data/train/훼손/454.png     18    18    18
# 2886   data/train/오염/138.png     10    10    10

# %%
train['err'] = train['pred'] == train['label']

# %%
err_ds = train.loc[(train['err'] == False)].copy()

# %%
img_err = err_ds['img_path'].values

# %%
plt.figure(figsize=(15,12))
for i in range(20):
    plt.subplot(5,4,i+1)
    im = Image.open(err_ds['img_path'].values[i])
    plt.imshow(im)
    plt.axis('off')
    tr = err_ds['label'].values[i]
    pr = err_ds['pred'].values[i]
    plt.title(f'true : {tr}, pred : {pr}')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-29-1e3219dae7ce> in <cell line: 2>()
#       2 for i in range(20):
#       3     plt.subplot(5,4,i+1)
# ----> 4     im = Image.open(err_ds['img_path'].values[i])
#       5     plt.imshow(im)
#       6     plt.axis('off')
#
# IndexError: index 7 is out of bounds for axis 0 with size 7

# %% [markdown]
# ## **test**

# %%
#test
test = pd.read_csv('data/test.csv')

# %%
test.head()
# Out:
#          id        img_path
# 0  TEST_000  ./test/000.png
# 1  TEST_001  ./test/001.png
# 2  TEST_002  ./test/002.png
# 3  TEST_003  ./test/003.png
# 4  TEST_004  ./test/004.png

# %%
test_dataset = CustomDataset(test['img_path'].values, None, test_transform)
test_loader = DataLoader(test_dataset, batch_size=CFG['BATCH_SIZE'], shuffle=False, num_workers=2)

# %%
def inference(model, test_loader, device):
    model.eval()
    preds = []
    with torch.no_grad():
        for imgs in tqdm(test_loader):
            imgs = imgs.float().to(device)
            
            pred = model(imgs)
            
            preds += pred.argmax(1).detach().cpu().numpy().tolist()
    
    #preds = le.inverse_transform(preds)
    return preds

# %%
preds = inference(infer_model, test_loader, device)
# Out:
#   0%|          | 0/23 [00:00<?, ?it/s]

# %% [markdown]
# ## **submit**

# %%
submit = pd.read_csv('data/sample_submission.csv')

# %%
submit['label'] = preds

# %%
submit.loc[submit['label'] == 0, 'label'] = '가구수정'
submit.loc[submit['label'] == 1, 'label'] = '걸레받이수정'
submit.loc[submit['label'] == 2, 'label'] = '곰팡이'
submit.loc[submit['label'] == 3, 'label'] = '꼬임'
submit.loc[submit['label'] == 4, 'label'] = '녹오염'
submit.loc[submit['label'] == 5, 'label'] = '들뜸'
submit.loc[submit['label'] == 6, 'label'] = '면불량'
submit.loc[submit['label'] == 7, 'label'] = '몰딩수정'
submit.loc[submit['label'] == 8, 'label'] = '반점'
submit.loc[submit['label'] == 9, 'label'] = '석고수정'
submit.loc[submit['label'] == 10, 'label'] = '오염'
submit.loc[submit['label'] == 11, 'label'] = '오타공'
submit.loc[submit['label'] == 12, 'label'] = '울음'
submit.loc[submit['label'] == 13, 'label'] = '이음부불량'
submit.loc[submit['label'] == 14, 'label'] = '창틀,문틀수정'
submit.loc[submit['label'] == 15, 'label'] = '터짐'
submit.loc[submit['label'] == 16, 'label'] = '틈새과다'
submit.loc[submit['label'] == 17, 'label'] = '피스'
submit.loc[submit['label'] == 18, 'label'] = '훼손'

# %%
submit.head()
# Out:
#          id label
# 0  TEST_000    훼손
# 1  TEST_001    오염
# 2  TEST_002    훼손
# 3  TEST_003    훼손
# 4  TEST_004    훼손

# %%
submit.to_csv('./ConvNeXtBase.csv', index=False)

# %%
# 모델 save
PATH = 'model.pickle'
torch.save(model.state_dict(), PATH)
